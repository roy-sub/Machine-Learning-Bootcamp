# %% [markdown]
# <a href="https://colab.research.google.com/github/roy-sub/Machine-Learning-Bootcamp/blob/main/Transfer_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras
from keras.applications.mobilenet_v2 import MobileNetV2

# %%
model = MobileNetV2()
model.summary()

# %%
import matplotlib.pyplot as plt
from keras.preprocessing import image

x = image.load_img('/content/vanilla-ice-cream-5-copy.jpg',target_size=(224,224))
plt.imshow(x)

# %%
import numpy as np
from keras.applications.mobilenet_v2 import preprocess_input,decode_predictions
x =image.img_to_array(x)  # Convert it into numpy array
x.shape
# Out:
# (224, 224, 3)

# %%
x = np.expand_dims(x,axis=0)
x.shape
# Out:
# (1, 224, 224, 3)

# %%
x = preprocess_input(x)
y = model.predict(x)
label = decode_predictions(y)
label
# Out:
# [[('n07614500', 'ice_cream', 0.79328454),
#   ('n07615774', 'ice_lolly', 0.019275593),
#   ('n07932039', 'eggnog', 0.016963199),
#   ('n07734744', 'mushroom', 0.015399024),
#   ('n07753592', 'banana', 0.014106501)]]

# %%
# !wget https://laurenslatest.com/wp-content/uploads/2020/08/vanilla-ice-cream-5-copy.jpg
# Out:
# --2021-03-02 13:02:54--  https://laurenslatest.com/wp-content/uploads/2020/08/vanilla-ice-cream-5-copy.jpg
# Resolving laurenslatest.com (laurenslatest.com)... 104.26.1.216, 104.26.0.216, 172.67.71.117, ...
# Connecting to laurenslatest.com (laurenslatest.com)|104.26.1.216|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 86382 (84K) [image/jpeg]
# Saving to: ‘vanilla-ice-cream-5-copy.jpg’
#
# vanilla-ice-cream-5 100%[===================>]  84.36K  --.-KB/s    in 0.02s
#
# 2021-03-02 13:02:54 (4.10 MB/s) - ‘vanilla-ice-cream-5-copy.jpg’ saved [86382/86382]
